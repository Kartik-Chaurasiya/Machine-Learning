# %% [markdown]
# <a href="https://colab.research.google.com/github/Syntax-code/Machine-Learning/blob/master/Multiple_linear_house_pricing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# β0 is known as the intercept.
#
# β0 to βi are known as coefficients.
#
# x1 to xi are the features of the data set.
#
# ε are the residual terms.

# %% [markdown]
# R squared: Accuracy of the multiple linear regression model
#
# yi is one value of y at index i.
#
# ŷ is pronounced as y hat and is the predicted values of y.
#
# y̅ is pronounced as y bar and is the average of y.
#
# ![image.png](data:image/png;base64,...)

# %%
# Clone the entire repo.
# !git clone -l -s https://github.com/Tan-Moy/medium_articles.git cloned-repo
# %cd cloned-repo
# !ls
# Out:
# Cloning into 'cloned-repo'...
# ...
# remote: Enumerating objects: 12, done.
# remote: Total 12 (delta 0), reused 0 (delta 0), pack-reused 12
# Unpacking objects: 100% (12/12), done.
# /content/cloned-repo
# art1_linear_regression	art2_multivariate_linear_regression

# %%
txt = open('art2_multivariate_linear_regression/home.txt')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(txt, index= False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-e9fd38df7ac5> in <module>()
# ----> 1 df = pd.read_csv(txt, index= False)
#
# TypeError: parser_f() got an unexpected keyword argument 'index'

# %%
df.columns = ['size', 'bedroom', 'price']

# %%
df.head()
# Out:
#    size  bedroom   price
# 0  1600        3  329900
# 1  2400        3  369000
# 2  1416        2  232000
# 3  3000        4  539900
# 4  1985        4  299900

# %%
df = (df - df.mean())/df.std()
df.head()
# Out:
#        size   bedroom     price
# 0 -0.495977 -0.226166 -0.073110
# 1  0.499874 -0.226166  0.236953
# 2 -0.725023 -1.526618 -0.849457
# 3  1.246762  1.074287  1.592190
# 4 -0.016724  1.074287 -0.311010
