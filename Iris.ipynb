# %% [markdown]
# <a href="https://colab.research.google.com/github/Syntax-code/Machine-Learning/blob/master/Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle --upgrade
# !kaggle --version
from google.colab import files
files.upload()
# Out:
# Requirement already up-to-date: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.6)
# ...
# Kaggle API 1.5.4
#      <input type="file" id="files-dd0a97de-3365-4d6e-9978-1d05924c37a5" name="files[]" multiple disabled />
#      <output id="result-dd0a97de-3365-4d6e-9978-1d05924c37a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# {}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

#chamge permission
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d uciml/iris
# Out:
# ...
#   0% 0.00/3.60k [00:00<?, ?B/s]
# 100% 3.60k/3.60k [00:00<00:00, 6.94MB/s]

# %%
# !unzip iris.zip
# Out:
# Archive:  iris.zip
#   inflating: Iris.csv
#   inflating: database.sqlite

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Iris.csv')
dataset.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
np.unique(dataset['Species'])
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
dataset.shape
# Out:
# (150, 6)

# %%
dataset.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
labelencoder = LabelEncoder()
dataset['Species'] = labelencoder.fit_transform(dataset['Species'])
dataset.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
np.unique(dataset['Species'])
# Out:
# array([0, 1, 2])

# %%
dataset.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 88    89            5.6           3.0            4.1           1.3        1
# 109  110            7.2           3.6            6.1           2.5        2
# 92    93            5.8           2.6            4.0           1.2        1
# 110  111            6.5           3.2            5.1           2.0        2
# 59    60            5.2           2.7            3.9           1.4        1

# %%
dataset.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
dataset.plot(kind='box', subplots=True, layout=(3,3),figsize=(16, 16), sharex = False, sharey = False)
plt.show()

# %%
dataset.hist()
plt.show()

# %%
pd.plotting.scatter_matrix(dataset, figsize = (20,20))
plt.show()

# %%
array = dataset.values
X = array[:,0:4]
Y = array[:,4]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-eade506380c5> in <module>()
# ----> 1 array = dataset.values
#       2 X = array[:,0:4]
#       3 Y = array[:,4]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'
